# %% [markdown]
# # PEMROGRAMAN BERBASIS OBJEK
#                                                 GAME "BANANA" WITH PYGAME
#                                     Dibuat untuk memenuhi tugas Ulangan Akhir Semester
# ![](/pygame/logo%20utm.png)
#
#                                                     Dosen Pengampu:
#                                                 Arik Kurniawati, S.Kom,M.T
#
#
#
#                                                       Dibuat Oleh:
#                                             Novi Duwi Saputri (180441100044)
#                                             Oktavia Dwi Iswahyuni (180441100048)
#
#
#                                                PROGRAM STUDI SISTEM INFORMASI
#                                                  JURUSAN TEKNIK INFORMATIKA
#                                                       FAKULTAS TEKNIK
#                                                 UNIVERSITAS  TRUNOJOYO MADURA
#                                                           2019

# %% [markdown]
# # PYGAME
#
# __A. PENGERTIAN PYGAME__
#
# __*Pygame*__ adalah seperangkat modul Python yang dirancang untuk membuat permainan. Pygame menambahkan fungsi di atas dengan sangat baik di SDL perpustakaan. Hal ini memungkinkan Anda untuk membuat sebuah game dengan fitur yang lengkap dan sebuah program multimedia dalam bahasa python. Pygame sangat portabel dan dapat berjalan pada hampir semua platform dan sistem operasi.
#
# __B. CARA INSTALASI PYGAME__
#
# Sebelum membuat game di python menggunakan modul python terlebih dahulu hal yang harus dilakukan adalah mendownload modul pygame pada aplikasi python. Berikut adalah langkah-langkah yang harus dilakukan untuk menginstal modul pygame pada python :
# 1.	Buka CMD, kemudian ketikkan “pip”
# 2.	Setelah muncul menu dari pip itu sendiri kemudian ketik “pip install pygame”
# 3.	Kemudian akan otomatis mendownload file instalasi modul pygame. Jika sudah muncul tulisan “Succesfully installed pygame -1.9.6”. Maka modul pygame pada apliikasi python sudah terinstall.

# %% [markdown]
# __C. VARIABEL GAME DAN PENJELASAN__
# ![](/pygame/1.png)
# ![](/pygame/2.png)
# ![](/pygame/3.png)
#
# __D. MAIN LOOPING GAME__
# ![](/pygame/4.png)
# ![](/pygame/5.png)
# ![](/pygame/6.png)

# %% [markdown]
# __E. PENJELASAAN CLASS__
#
# Class pada game ini mewarisi class sprite yang dimiliki pygame
# ![](/pygame/sprite.png)
#
# __1. Class Player__
# ![](/pygame/7.png)
# Pada class player ini terdapat 3 method yaitu:
#
# A.Inisialisasi
#
#     - Sprite harus mewarisi sprite yang ada pada library pygame
#     - pygame.image.load untuk menampilkan asset gambar yang ada dalam game
#     - self.vx dan vy untuk menentukan posisi dari pemain
#     - shield untuk banyaknya nyawa player
#     - shoot_delay digunakan untuk banyak peluru yang keluar dari player
#
# B.Update
#
#     - key.get_pressed() untuk mendeteksi keyboard yang ditekan
#     - method update ini digunakan untuk mengatur tombol pada keyboard yang akan digunakan pada game
#
# C.Shoot
#
#     - time.get_ticks() digunakan untuk mendapatkan waktu saat menembak
#     - dan shoot mewarisi dari class bullet untuk menembak
#
# __2. Class Bullet__
# ![](/pygame/8.png)
# Pada class Bullet ini terdapat 2 method yaitu:
#
# A.Inisialisasi
#
#     - Sprite harus mewarisi sprite yang ada pada library pygame
#     - pygame.image.load untuk menampilkan asset gambar yang ada dalam game
#
# B.Update
#
#     - self.rect.y digunakan untuk mengatur kecepatan dari bullet
#
# __3. Class Banana__
# ![](/pygame/9.png)
# Pada class Banana ini terdapat 2 method yaitu:
#
# A.Inisialisasi
#
#     - Sprite harus mewarisi sprite yang ada pada library pygame
#     - pygame.image.load untuk menampilkan asset gambar yang ada dalam game
#     - random.randrange untuk memunculkan pisang secara acak
#     - speedy untuk mengatur kecepatan dari random pisang
#
# B. Update
#
#     - method ini untuk memunculkan pisang secara acak
#
# __4. Class Bom__
# ![](/pygame/10.png)
# Pada class Banana ini terdapat 2 method yaitu:
#
# A.Inisialisasi
#
#     - Sprite harus mewarisi sprite yang ada pada library pygame
#     - pygame.image.load untuk menampilkan asset gambar yang ada dalam game
#     - random.randrange untuk memunculkan rubah secara acak
#     - speedy untuk mengatur kecepatan dari random pisang
#
# B. Update
#
#     - method ini untuk memunculkan rubah secara acak
#
# __F. IMPLEMENTASI MATERI OOP__
#
# Konsep OOP yang di gunakan dalam game ini adalah Inheritance(Pewarisan) yaitu superclass (super().__init__())
# ![](/pygame/OOP1.png)
# ![](/pygame/OOP2.png)
#
# __G. SCREENSHOOT JALANNYA GAME__
#
# - Tampilan awal
# ![](/pygame/awal.png)
#
# - Tampilan ketika main
# ![](/pygame/main.png)
#
# - Tampilan Game Over dan tap continue
# ![](/pygame/game%20over.png)
